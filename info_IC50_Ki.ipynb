# %%
from chembl_webresource_client.new_client import new_client
from chembl_webresource_client.query_set import QuerySet
import pandas as pd
from os import mkdir
from loguru import logger

try:
  mkdir("results")
except:
  pass

# %%
df = pd.read_csv("../results/targets/targets_data_from_ChEMBL.csv", sep=';') 
new_df = df[["target_chembl_id", "IC50", "Ki", "IC50_new", "Ki_new"]]
new_df
# Out:
#    target_chembl_id   IC50     Ki  IC50_new  Ki_new
# 0        CHEMBL2034   4413   2195      1712     920
# 1         CHEMBL210   1597   1710       588     550
# 2         CHEMBL211   1543   2802       555    1445
# 3         CHEMBL213   1541   1333       555     358
# 4         CHEMBL214    770   6029       490    4538
# 5        CHEMBL1867   1038   1926       226     823
# 6        CHEMBL1871   3762   1152      1913     858
# 7         CHEMBL216   2018   2552       739    1243
# 8         CHEMBL217   2167  12125       740    7125
# 9        CHEMBL1951   5282   1557      2550     536
# 10        CHEMBL218   3155   6296      1461    2970
# 11       CHEMBL2056   1081   2707       149    1131
# 12        CHEMBL220   9091   1925      5660     571
# 13        CHEMBL222   3458   3016      2017    1653
# 14       CHEMBL1898    370   1274       272     824
# 15        CHEMBL224   2105   6068      1073    3879
# 16        CHEMBL228   4539   4104      2719    2376
# 17        CHEMBL229    304   1962       224    1359
# 18        CHEMBL231   1294   2788       311    1305
# 19        CHEMBL233   2423   6583       983    4327
# 20        CHEMBL236   2509   6028       922    3637
# 21        CHEMBL240  15530   2764      8180    1311
# 22        CHEMBL245   1805   2832       768    1445
# 23       CHEMBL1833   1178   2666       335    1441
# 24        CHEMBL252   2512   1133      1292     235
# 25        CHEMBL251   1564   8206       429    4890
# 26        CHEMBL253   1776   6227      1092    3854
# 27        CHEMBL258   3581   1923      1665     390
# 28       CHEMBL4777   1488   1725       399     535
